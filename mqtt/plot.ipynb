# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('results.csv')
sns.barplot(data=df, y = 'steps_learning', x='broker', hue='alg')
# Out:
# <AxesSubplot: xlabel='broker', ylabel='steps_learning'>

# %%
df = pd.read_csv('results.csv')
sns.barplot(data=df, y = 'queries_learning', x='broker', hue='alg')
# Out:
# <AxesSubplot: xlabel='broker', ylabel='queries_learning'>

# %%
df = pd.read_csv('results.csv')
sns.barplot(data=df, y = 'automaton_size', x='broker', hue='alg')
# Out:
# <AxesSubplot: xlabel='broker', ylabel='automaton_size'>
